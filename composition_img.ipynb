# %%
import numpy as np
import cv2
from torch.utils.data.dataset import Dataset
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os, sys, re
import math
from skimage import measure
import time, datetime
from codes.img_preprocessing import *
from codes.compo import composition

# %%
composition('/home/thesard/Documents/Env_DMLA/results/005_AU_R/IR OD/patch_size_15/weighted/sigma5/BCM',overlap=False)
