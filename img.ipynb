# %%
import matplotlib.pyplot as plt
import cv2

# %%
f, axarr = plt.subplots(1,3,figsize=(15,10))

plt.rc('font', size=10)  

axarr[0].imshow(cv2.imread('1.png',0),cmap='gray')
axarr[1].imshow(cv2.imread('2.png',0),cmap='gray')
axarr[2].imshow(cv2.imread('BCM_20171011_to_20180618_threshold_1_otsu_27.png',0),cmap='gray')

# plt.suptitle("Example")

f.savefig('example.png')
